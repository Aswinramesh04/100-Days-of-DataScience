# %% [markdown]
# <a href="https://colab.research.google.com/github/Aswinramesh04/100-DaysOfCode-DataScience/blob/main/Day42_Implementation_SVM_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#                           Day42 SVM Regression       By:Loga Aswin

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **Data Pre-processing :**

# %%
df = pd.read_csv('/content/Salary_dataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.413333   76004.000000
# std           2.837888   27414.429785
# min           1.200000   37732.000000
# 25%           3.300000   56721.750000
# 50%           4.800000   65238.000000
# 75%           7.800000  100545.750000
# max          10.600000  122392.000000

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
X = df.drop('Salary', axis=1)
Y = df['Salary']

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(X, Y, test_size=0.20, random_state=42)

# %% [markdown]
# **Create and Train SVM**

# %%
from sklearn.svm import SVR

svr = SVR(kernel='linear')
svr.fit(x_train, y_train)
# Out:
# SVR(kernel='linear')

# %% [markdown]
# **Predict Test Results :**

# %%
y_pred = svr.predict(x_test)
pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})
# Out:
#       Actual  Predicted
# 27  112636.0   62472.76
# 15   67939.0   62205.33
# 23  113813.0   62393.10
# 17   83089.0   62228.09
# 8    64446.0   62108.60
# 9    57190.0   62137.05

# %%
# Evaluate Model Performance :

from sklearn.metrics import mean_absolute_error, mean_squared_error

mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 22577.028333225255

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 943057673.9043975

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# 30709.244111576525
