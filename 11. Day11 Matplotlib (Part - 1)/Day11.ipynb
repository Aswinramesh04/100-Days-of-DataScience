# %% [markdown]
# <a href="https://colab.research.google.com/github/Aswinramesh04/100-DaysOfCode-DataScience/blob/main/Day11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#                   Matplotlib Tutorial  (Part 1) -- Loga Aswin

# %% [markdown]
# **Table of Contents**

# %% [markdown]
# Overview of Data Visualization
#
# Intro. to Matplotlib
#
# Import Matplotlib
#
# Display Plots in Matplotlib
#
# Matplotlib interfaces
#
# Figure and Subplots
#
# Matplotlib Simple Plot
#
# Line Plot
#
# Scatter Plot
#
# Bar Chart
#
# Histogram
#
# Horizontal Bar Chart
#
# Error Bar Chart
#
# Stacked Bar Chart
#
# Pie Chart
#
# Box Plot
#
# Area Chart
#
# Contour Plot
#
# Styles with Matplotlib Plots
#
# grid Adding
#
# Handling axes
#
# Handling X and Y ticks
#
# labels Adding
#
# title Adding

# %% [markdown]
# **Overview of Data Visualization**

# %% [markdown]
# These Python data visualization tools are as follows:-
#
# • Matplotlib
#
# • Seaborn
#
# • plotly
#
# • ggplot

# %% [markdown]
# **Intro. to Matplotlib**

# %% [markdown]
# Matplotlib is a widely-used Python library for creating static, animated, and interactive visualizations in data science and scientific computing.

# %% [markdown]
# Few key features are : High-Quality Plots, Cross-Platform,
# Integration with Other Libraries,
# Customization, Multiple Interfaces.

# %% [markdown]
# **Import Libraries**

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
plt.show()  # to display

# %%
# Sample
plt.plot([1, 3, 2, 4])

plt.show( )

# %% [markdown]
# **Figure and Axes**

# %%
fig = plt.figure()

ax = plt.axes()

# %% [markdown]
# **Figure and Subplots**

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)

ax2 = fig.add_subplot(2, 2, 2)

ax3 = fig.add_subplot(2, 2, 3)

ax4 = fig.add_subplot(2, 2, 4)

# %% [markdown]
# **Saving the Plot**

# %%
fig.savefig('plot1.png')

# %% [markdown]
# **Line Plot**

# %% [markdown]
# A line plot is used to represent data points connected by straight lines. It's commonly used for showing trends over a continuous interval.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y)

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot - Aswin')

# Display the plot
plt.show()

# %% [markdown]
# **Bar Plot**

# %% [markdown]
# A bar plot (or bar chart) is used to represent categorical data with rectangular bars. It's suitable for comparing categories or showing the distribution of data.

# %%
categories = ['A', 'B', 'C', 'D']
values = [10, 25, 15, 30]
plt.bar(categories, values)

plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Plot - Aswin')

plt.show()

# %% [markdown]
# **Scatter Plot**

# %% [markdown]
# A scatter plot is used to visualize the relationship between two variables. Each point on the plot represents a data point with two values.

# %%
x = [10, 20, 30, 40, 50]
y = [20, 40, 30, 50, 60]

plt.scatter(x, y)

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot - Aswin')

plt.show()

# %% [markdown]
# **Pie Chart**

# %% [markdown]
# A pie chart is used to represent the parts of a whole. It's suitable for showing the proportions or percentages of different categories within a dataset.

# %%
labels = ['A', 'B', 'C', 'D']
sizes = [150, 300, 250, 200]

plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=10)

plt.title('Pie Chart Example')

plt.show()
